# %%
# Create a dictionary to store college information
college = {
    "name": "ABC Institute",  # College name

    # List of departments
    "departments": [
        {
            "name": "CSE",      # Department name
            "students": 120     # Number of students
        },
        {
            "name": "ECE",      # Department name
            "students": 90      # Number of students
        }
    ]
}

# Print the name of the first department
print(college["departments"][0]["name"])
# Out:
# CSE
